# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sahanbcs\anaconda3\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sahanbcs\anaconda3\lib\site-packages (from opencv-python) (1.19.5)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong','welcome','peace']
number_imgs = 8

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting images for thumbsdown
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting images for thankyou
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting images for welcome
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting images for peace
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in c:\users\sahanbcs\anaconda3\lib\site-packages (5.12.3)
# Collecting pyqt5
#   Using cached PyQt5-5.15.4-cp36.cp37.cp38.cp39-none-win_amd64.whl (6.8 MB)
# Requirement already satisfied: lxml in c:\users\sahanbcs\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\sahanbcs\anaconda3\lib\site-packages (from pyqt5) (12.9.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in c:\users\sahanbcs\anaconda3\lib\site-packages (from pyqt5) (5.15.2)
# Installing collected packages: pyqt5
#   Attempting uninstall: pyqt5
#     Found existing installation: PyQt5 5.12.3
#     Uninstalling PyQt5-5.12.3:
#       Successfully uninstalled PyQt5-5.12.3
# Successfully installed pyqt5-5.15.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, but you have pyqt5 5.15.4 which is incompatible.

# %%
# !pip list
# Out:
# Package                            Version             Location
# ---------------------------------- ------------------- ------------------------------------------------------------------------------------------------------
# absl-py                            0.14.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.5
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# glob2                              0.7
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# helpdev                            0.7.1
# html5lib                           1.1
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lvis                               0.5.3
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# object-detection                   0.1
# olefile                            0.46
# opencv-python                      4.5.3.56
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.0.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# PyQt5                              5.15.4
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.9.0
# PyQtWebEngine                      5.12.1
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# slim                               0.1                 c:\users\sahanbcs\desktop\local disk (d)\programming\python\ditaection\tensorflow\models\research\slim
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# tf-models-official                 2.6.0
# tf-slim                            1.1.0
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wget                               3.2
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\livelong\livelong.5a8d82d9-1f4a-11ec-9ee9-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/livelong/livelong.5a8d82d9-1f4a-11ec-9ee9-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\livelong\livelong.5bc5547b-1f4a-11ec-bc44-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages
60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.271344ea-1f4a-11ec-948d-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.271344ea-1f4a-11ec-948d-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.675288ad-1efb-11ec-aeb0-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.675288ad-1efb-11ec-aeb0-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.29802839-1f4a-11ec-beeb-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.29802839-1f4a-11ec-beeb-60f6779b1797.xml
# Cancel creation.
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.6bab416d-1f4a-11ec-a701-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.6bab416d-1f4a-11ec-a701-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.6ce66c32-1f4a-11ec-a35f-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.6ce66c32-1f4a-11ec-a35f-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.6e1c6a36-1f4a-11ec-aff9-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.6e1c6a36-1f4a-11ec-aff9-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.6f5294e6-1f4a-11ec-9b7e-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.6f5294e6-1f4a-11ec-9b7e-60f6779b1797.xml
# labelImg.py:965: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.71c10065-1f4a-11ec-990f-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.71c10065-1f4a-11ec-990f-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.72fec14a-1f4a-11ec-9357-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.72fec14a-1f4a-11ec-9357-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.7088dfef-1f4a-11ec-80db-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.7088dfef-1f4a-11ec-80db-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.74357de6-1f4a-11ec-8d33-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.74357de6-1f4a-11ec-8d33-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.a3cec9e2-1efb-11ec-8992-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.a3cec9e2-1efb-11ec-8992-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.a28d13ed-1efb-11ec-b4f6-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.a28d13ed-1efb-11ec-b4f6-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.a79fcb61-1efb-11ec-893d-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.a79fcb61-1efb-11ec-893d-60f6779b1797.xml
# Image:C:\Users\sahanbcs\Desktop\Local Disk (D)\Programming\Python\Ditaection\Tensorflow\workspace\images\collectedimages\welcome\welcome.a515fbee-1efb-11ec-b434-60f6779b1797.jpg -> Annotation:C:/Users/sahanbcs/Desktop/Local Disk (D)/Programming/Python/Ditaection/Tensorflow/workspace/images/collectedimages/welcome/welcome.a515fbee-1efb-11ec-b434-60f6779b1797.xml

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
if not os.path.exists(TRAIN_PATH):
    # !mkdir {TRAIN_PATH}
if not os.path.exists(TEST_PATH):
    # !mkdir {TEST_PATH}

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
